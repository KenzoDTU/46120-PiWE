# %% [markdown]
# # Matplotlib Exercise: Visualizing Correlated Gaussian Random Variables

# %% [markdown]
# Now that we know how to generate correlated random variables, let's visualize them.
#
# ### Exercise
#
# Make the following plots. All plots must have x and y labels, titles, and legends if there is more than one dataset in the same axes.
#
# 1. Overlaid histograms of your samples of uncorrelated random variables with 30 bins (use `histtype='step'`)
# 2. A scatterplot of $X_2$ vs $X_1$ with marker size equal to 2. Overlay the the theoretical line ($y=x$) in a black, dashed line.
# 3. Overlaid histograms of your samples of correlated random variables with 30 bins (use `histtype='step'`)
#
# ### Hints
#
# - In the arrays of random variables, each row `i` corresponds to a *sample* of random variable `i` (just FYI).
# - Google is your friend :)

# %%
import matplotlib.pyplot as plt  # need to import matplotlib, of course
import numpy as np  # import any needed modules here

# %%
n_real = int(1E6)  # number of realizations
n_vars = 3  # number of random variables we want to correlate
cov = np.array([[ 1. ,  0.2,  0.4], [ 0.2,  0.8,  0.3], [ 0.4,  0.3,  1.1]])  # covariance matrix

# %%
unc_vars = np.random.randn(n_vars, n_real)  # create [n_vars x n_real] array of uncorrelated (unc) normal random variables

# %%
chol_mat = np.linalg.cholesky(cov)  # calculate the cholesky decomposition of the covariance matrix

# %%
cor_vars = chol_mat @ unc_vars  # [n_vars x n_real] array of correlated (cor) random variables

# %%
cor_vars.var(axis=1)  # calculate variances of each sample of random variables
# Out:
# array([0.99961374, 0.80149816, 1.10079572])

# %%
np.corrcoef(cor_vars[0, :], cor_vars[1, :])  # calculate the correlation coefficient between the first and second random samples
# Out:
# array([[1.        , 0.22552356],
#        [0.22552356, 1.        ]])

# %% [markdown]
# ## Plot 1: Histogram of Uncorrelated Variables

# %% [markdown]
# Make a plot with overlaid histograms of your samples of uncorrelated random variables with 30 bins (use histtype='step').

# %%
fig = plt.figure()  # create a figure
plt.hist(cor_vars, bins=30, histtype='step')  # histogram of the first sample of correlated random variables
plt.xlabel("Value")  # label x-axis
plt.ylabel("Frequency")  # label y-axis
plt.title("Histogram of Correlated Random Variables")  # title of the plot
plt.show()  # show the plot
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 fig = plt.figure()  # create a figure
# ----> 2 plt.hist(cor_vars, bins=30, histtype='step')  # histogram of the first sample of correlated random variables
#       3 plt.xlabel("Value")  # label x-axis
#       4 plt.ylabel("Frequency")  # label y-axis
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3224, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3199 @_copy_docstring_and_deprecators(Axes.hist)
#    3200 def hist(
#    3201     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3222     BarContainer | Polygon | list[BarContainer | Polygon],
#    3223 ]:
# -> 3224     return gca().hist(
#    3225         x,
#    3226         bins=bins,
#    3227         range=range,
#    3228         density=density,
#    3229         weights=weights,
#    3230         cumulative=cumulative,
#    3231         bottom=bottom,
#    3232         histtype=histtype,
#    3233         align=align,
#    3234         orientation=orientation,
#    3235         rwidth=rwidth,
#    3236         log=log,
#    3237         color=color,
#    3238         label=label,
#    3239         stacked=stacked,
#    3240         **({"data": data} if data is not None else {}),
#    3241         **kwargs,
#    3242     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6984, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6980 # add patches in reverse order so that when stacking,
#    6981 # items lower in the stack are plotted on top of
#    6982 # items higher in the stack
#    6983 for x, y, color in reversed(list(zip(xvals, yvals, colors))):
# -> 6984     patches.append(self.fill(
#    6985         x[:split], y[:split],
#    6986         closed=True if fill else None,
#    6987         facecolor=color,
#    6988         edgecolor=None if fill else color,
#    6989         fill=fill if fill else None,
#    6990         zorder=None if fill else mlines.Line2D.zorder))
#    6991 for patch_list in patches:
#    6992     for patch in patch_list:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5302, in Axes.fill(self, data, *args, **kwargs)
#    5300 patches = [*self._get_patches_for_fill(self, *args, data=data, **kwargs)]
#    5301 for poly in patches:
# -> 5302     self.add_patch(poly)
#    5303 self._request_autoscale_view()
#    5304 return patches
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:2384, in _AxesBase.add_patch(self, p)
#    2382 if p.get_clip_path() is None:
#    2383     p.set_clip_path(self.patch)
# -> 2384 self._update_patch_limits(p)
#    2385 self._children.append(p)
#    2386 p._remove_method = self._children.remove
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:2410, in _AxesBase._update_patch_limits(self, patch)
#    2408     _, dzeros = curve.axis_aligned_extrema()
#    2409     # Calculate vertices of start, end and any extrema in between
# -> 2410     vertices.append(curve([0, *dzeros, 1]))
#    2412 if len(vertices):
#    2413     vertices = np.vstack(vertices)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/bezier.py:215, in BezierSegment.__call__(self, t)
#     201 """
#     202 Evaluate the Bézier curve at point(s) *t* in [0, 1].
#     203
#    (...)
#     212     Value of the curve for each point in *t*.
#     213 """
#     214 t = np.asarray(t)
# --> 215 return (np.power.outer(1 - t, self._orders[::-1])
#     216         * np.power.outer(t, self._orders)) @ self._px
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plot 2: Scatterplot of X2 vs. X1

# %% [markdown]
# Make a scatterplot of $X_2$ vs $X_1$ with marker size equal to 2. Overlay the the theoretical line ($y=x$) in a black, dashed line.

# %%
  # insert code here

# %% [markdown]
# ## Plot 3: Histogram of Correlated Variables

# %% [markdown]
# Make a plot with overlaid histograms of your samples of uncorrelated random variables with 30 bins (use histtype='step').

# %%
  # insert code here
